# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
text=["I love this movie,its fantastic!",
      "Its okay ,not too bad",
      "I hated the movie. very diasappointed"]
sia=SentimentIntensityAnalyzer()
for t in text:
  scores=sia.polarity_scores(t)
  compound=scores['compound']
  sentiment=("positive" if compound>0.05 else "negative" if compound<0.05 else "neutral")
  print(t)
  print(scores)
  print(sentiment)
# Out:
# I love this movie,its fantastic!
# {'neg': 0.0, 'neu': 0.198, 'pos': 0.802, 'compound': 0.8439}
# positive
# Its okay ,not too bad
# {'neg': 0.0, 'neu': 0.387, 'pos': 0.613, 'compound': 0.5789}
# positive
# I hated the movie. very diasappointed
# {'neg': 0.512, 'neu': 0.488, 'pos': 0.0, 'compound': -0.6369}
# negative
